# %% [markdown]
# # Evaluation of varying alpha

# %%
import numpy as np

# !mkdir "./results/alpha_varied"

DEST_DIR = "./results/alpha_varied"
ANALYSIS_METHODS = ["proposed", "Igarashi", "Saidi"]
DAG_PATH = "./DAGs/reference_system/referenceSystem.dot"
JITTER_SRC = "./DAGs/reference_system/reference_system_exec_jitter_multi_8core_8192.yaml"
ALPHA_VALUES = np.arange(1.4, 2.0, 0.0006)

for method in ANALYSIS_METHODS:
    for seed, alpha in enumerate(ALPHA_VALUES):
        # %run eval_interface.py -d $DEST_DIR -g $DAG_PATH -m $method --alpha $alpha -c 8 -a "LLF" -u -j $JITTER_SRC 1.7 $seed

# EDF
for seed, alpha in enumerate(ALPHA_VALUES):
    # %run eval_interface.py -d $DEST_DIR -g $DAG_PATH -m "Igarashi" --alpha $alpha -c 8 -a "EDF" -u -j $JITTER_SRC 1.7 $seed
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Documents\workspace\env\DED\DED_Simulator\eval_interface.py:89, in <module>
#      87 dag.set_num_trigger()
#      88 if jitter:
# ---> 89     jitter_generator = JitterGenerator(*jitter)
#      90     jitter_generator.set_wcet(dag)
#      91 JobGenerator.generate(dag)
#
# File ~\Documents\workspace\env\DED\DED_Simulator\src\jitter_generator.py:17, in JitterGenerator.__init__(self, jitter_src_path, factor, seed)
#      10 def __init__(
#      11     self,
#      12     jitter_src_path: str,
#      13     factor: str,
#      14     seed: Optional[int] = None
#      15 ) -> None:
#      16     with open(jitter_src_path, "r") as f:
# ---> 17         jitter_src = yaml.safe_load(f)
#      18     self._node_name_dict = jitter_src['node_name_dict']
#      19     self._jitter_dict = jitter_src['jitter']
#
# ...
